# %%
import requests
import json
import pandas as pd
from pprint import pprint
import pandas 
import numpy as np

# %%
url = "https://jobs.github.com/positions.json?description=api"

# %%
#response = requests.get(url)

# %%
response = requests.get(url).json()

# %%
#data = response.json()
pprint(response)
# Out:
# [{'company': 'Randstad Groep Nederland B.V.',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBdWloIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--9cc2304d0d0f55e04318a962f1ae39008fb08adf/randstad-logo-share-blue.png',
#   'company_url': 'https://www.werkenbijrandstad.nl/',
#   'created_at': 'Fri Apr 23 08:23:08 UTC 2021',
#   'description': '<p>Data Engineer, Everyday people employed through Randstad '
#                  'make sure your luggage gets onto the plane, your takeaway '
#                  'into your kitchen and that our most vulnerable are cared '
#                  'for. Everytime we place someone into a new role, they make '
#                  'an impact on our society, and we make an impact on their and '
#                  'their employer’s future. As a more and more data-driven '
#                  'organisation, data is a vital part of delivering on the '
#                  'promises we make to our candidates and customers.</p>\n'
#                  '<p>Randstad, Yacht and Tempo-Team possess an enormous '
#                  'quantity of data: the characteristics of millions of '
#                  'candidates and business data on clients, potentials and our '
#                  'own organisation. Your team, DataHub, is responsible for '
#                  'providing the basis for our data infrastructure. Our data '
#                  'engineers work on a self-service data platform, making sure '
#                  'our data makes its way from a vast array of sources to the '
#                  'right place, enabling our Data Scientists and Operational '
#                  'Insights teams to for example build AI solutions.</p>\n'
#                  '<p><strong>DATA ENGINEER TEAM</strong></p>\n'
#                  '<p>The DataHub team is an agile team of 8 data engineers. '
#                  'The datalake we maintain is partly in Redshift, partly in '
#                  'S3. We created a Django based metadata catalog, that '
#                  'functions in the same time as a portal to monitor the data '
#                  'and to provide services for our consumers.</p>\n'
#                  '<p>For general usage we offer the functionality of data '
#                  'subscriptions through scheduled unloads to a project space '
#                  'on S3. Furthermore we offer tools to work with machine '
#                  'learning models using Sagemaker.</p>\n'
#                  '<p>The Data Engineer will be designing and setting up '
#                  'infrastructure on AWS for the expanding services of our '
#                  'platform and develop airflow dags that represent our data '
#                  'pipelines. Most of our coding is done in python.</p>\n'
#                  '<p><strong>WHAT WILL YOU BE DOING AS A DATA '
#                  'ENGINEER?</strong></p>\n'
#                  '<p>You will be part of an agile Data Engineer team and play '
#                  'a vital role in the design and development of a cloud-based '
#                  'data platform.</p>\n'
#                  '<p>You will build and manage the DataHub frontend, which '
#                  'includes;</p>\n'
#                  '<ul>\n'
#                  '<li>A data catalog;</li>\n'
#                  '<li>DataHub users and projects management;</li>\n'
#                  '<li>Data subscriptions;</li>\n'
#                  '<li>etc.</li>\n'
#                  '</ul>\n'
#                  '<p>Develop ways to improve self-service data consumption and '
#                  'data publishing:</p>\n'
#                  '<ul>\n'
#                  '<li>Build and manage ETL pipelines in Airflow, which are '
#                  'responsible of ingesting the data and making the data '
#                  'available to users;</li>\n'
#                  '<li>Develop standard ways to deliver data in the '
#                  'DataHub;</li>\n'
#                  '<li>Develop CI/CD pipelines for data consuming teams to let '
#                  'them develop their products;</li>\n'
#                  '<li>etc.</li>\n'
#                  '</ul>\n'
#                  '<p>The Data Engineer will be responsible of producing high '
#                  'quality code and reusable components. Using '
#                  'containerization, CI/CD and other automation technologies, '
#                  'you will be responsible for creating a backend for high '
#                  'availability and scalability, while at the same time being '
#                  'easily deployable, manageable and secure.</p>\n'
#                  '<p>Together with the rest of the team you will be involved '
#                  'in the full product development process, from design, '
#                  'implementation, to testing, documentation and automated '
#                  'deployment.</p>\n'
#                  '<p>Respond to and resolve operational incidents, performing '
#                  'root cause analysis and managing changes required to prevent '
#                  'future occurrences.</p>\n'
#                  '<p>In this team you will have a wide range of '
#                  'responsibilities and should be willing to adapt to many '
#                  'different challenges.</p>\n'
#                  '<p>Discuss with the users of the platform requirements and '
#                  'future improvements, but also come with proposals for our '
#                  'user on how to use the platform.</p>\n'
#                  '<p>Manage and develop our data persistence environments '
#                  '(data lake, storage, etc) to ensure that data is properly '
#                  'available to users and secured</p>\n'
#                  '<p>Monitor systems for uptime and performance.</p>\n'
#                  '<p><strong>WHAT IS OUR STACK?</strong></p>\n'
#                  '<ul>\n'
#                  '<li>Python;</li>\n'
#                  '<li>ECS, Docker;</li>\n'
#                  '<li>CloudFormation, Jenkins;</li>\n'
#                  '<li>Airflow;</li>\n'
#                  '<li>AWS (S3, EC2, ECS, lambda, RDS, Redshift, EMR Spark, '
#                  'Athena, Glue).</li>\n'
#                  '</ul>\n'
#                  '<p><strong>WHAT WE WOULD LIKE YOU TO KNOW AND BRING TO THE '
#                  'TABLE?</strong></p>\n'
#                  '<ul>\n'
#                  '<li>Our small, agile teams are just that: agile. You should '
#                  'be able to adapt to a variety of challenges and like quick '
#                  'feedback loops;</li>\n'
#                  '<li>Experience working in our tech stack, including Python, '
#                  'Linux, AWS cloud, Jenkins and GIT;</li>\n'
#                  '<li>Experience with scripting/automation of tasks;</li>\n'
#                  '<li>Experience with common devops and CI/CD practices to '
#                  'make your own work as easy as possible and guarantee the '
#                  'quality of our products;</li>\n'
#                  '<li>Be comfortable working in test-driven development and '
#                  'know what this means;</li>\n'
#                  '<li>Like working in a team, but take responsibility for your '
#                  'own tasks;</li>\n'
#                  '<li>If you really want to impress us, you can do so by '
#                  'having experience in:containerization platforms like ECS, '
#                  'EKS and Docker; Redshift; AWS serverless services (Lambda, '
#                  'API GW, SNS); SQL databases; Django; Airflow.</li>\n'
#                  '</ul>\n'
#                  '<p><strong>WHAT DO WE OFFER?</strong></p>\n'
#                  '<ul>\n'
#                  '<li>Plenty of training and development opportunities within '
#                  'the group. A significant share of our employees have held '
#                  'several roles in their years in the business, with RGN '
#                  'giving you the tools you need to challenge and develop '
#                  'yourself;</li>\n'
#                  '<li>A monthly salary between €2.666 and €5.406, depending on '
#                  'your experience;</li>\n'
#                  '<li>8,5% holiday allowance;</li>\n'
#                  '<li>A generous monthly benefit budget on top of your salary '
#                  'and holiday pay that you can choose to spend on extra time '
#                  'off, perks such as a bike, tablet, gym subscription or '
#                  'simply get paid out;</li>\n'
#                  '<li>25 days holiday with the option to buy additional 25 '
#                  'days off;</li>\n'
#                  '<li>A generous sabbatical program;</li>\n'
#                  '<li>A good mobility scheme, laptop and everything you need '
#                  'to perform your job well;</li>\n'
#                  '<li>An attractive bonus scheme and the option to earn an '
#                  'outperformance bonus twice per year.</li>\n'
#                  '</ul>\n'
#                  '<p>Does this sound like the right next step for you? '
#                  'Fantastic! We are looking forward to your application.</p>\n'
#                  '<p>--</p>\n',
#   'how_to_apply': '<p>Apply directly through <a '
#                   'href="https://www.werkenbijrandstad.nl/nl/nl/apply?jobSeqNo=RANEUKR18598EXTERNALNLNL&amp;utm_source=github&amp;utm_medium=paid&amp;utm_campaign=cr-it"><strong>the '
#                   'application form</strong></a>!</p>\n',
#   'id': '4502c26a-af2f-4cd1-a3e4-a25cf813bfbf',
#   'location': 'Diemen/Amsterdam',
#   'title': 'Data Engineer',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/4502c26a-af2f-4cd1-a3e4-a25cf813bfbf'},
#  {'company': 'Randstad Groep Nederland B.V.',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBdGVoIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--38e47b1190f9c22b506812abe9a0fe4161cc4b85/randstad-logo-share-blue.png',
#   'company_url': 'https://www.werkenbijrandstad.nl/',
#   'created_at': 'Thu Apr 22 16:15:11 UTC 2021',
#   'description': '<p>Als je bij Randstad Groep Nederland IT werkt, houd je '
#                  'jezelf en Nederland in beweging. Stilstand is achteruitgang, '
#                  'daarom zijn we continu bezig onze business en processen te '
#                  'optimaliseren, zodat we onze klanten en kandidaten meer '
#                  'gemak, snelheid en transparantie kunnen bieden. Impactvolle '
#                  'tech, daar doen we het voor.</p>\n'
#                  '<p>Zo werken we in onze 24 devops teams aan onder andere '
#                  'customer experience initiatieven, state of the art tooling '
#                  'voor onze intercedenten, sales consultants en recruiters, en '
#                  'investeren we sterk in data, om data driven te werken binnen '
#                  'een menselijke wereld. Zo hebben we de talent recommender, '
#                  'een AI oplossing die binnen seconden passende kandidaten '
#                  'vindt; moderniseren wij onze kern door legacy systemen op te '
#                  'breken naar applicaties en verplaatsen we steeds meer naar '
#                  'de cloud.</p>\n'
#                  '<p><strong>WAT GA JE DOEN?</strong></p>\n'
#                  '<ul>\n'
#                  '<li>Je ondersteunt de lead enterprise archtiect met het '
#                  'geven van technische invulling aan de transformatie op '
#                  'business, technologie en persoonlijk vlak;</li>\n'
#                  '<li>Samen met de andere architecten werk je de roadmap van '
#                  'RGN IT uit;</li>\n'
#                  '<li>Nauw samenwerken met de product owners en tech leads, '
#                  'discussies begeleiden, sessies faciliteren om een op elkaar '
#                  'aansluitende, business ondersteunende visie en '
#                  'kwaliteitsstandaarden te creëren;</li>\n'
#                  '<li>Adviseren van productteams en developers op '
#                  'kwaliteitsnormen en verbeteringsmogelijkheden;</li>\n'
#                  '<li>Vertalen van strategie en functionele wensen naar '
#                  'verbeteringen in ons applicatielandschap;</li>\n'
#                  '<li>Samen met de andere architecten ben je het technisch '
#                  'geweten van RGN IT;</li>\n'
#                  '<li>Operationaliseren van architectuur, naast ‘as is’ en ‘to '
#                  'be’ ook de route hiernaartoe uitwerken.</li>\n'
#                  '</ul>\n'
#                  '<p><strong>MET WIE WERK JE SAMEN?</strong></p>\n'
#                  '<p>Als software architect werk je in ons architecture team, '
#                  'als onderdeel van onze foundation tribe, samen met 5 andere '
#                  'architecten onder leiding van de lead enterprise '
#                  'architect.Samen zijn jullie het technisch geweten van ons '
#                  'applicatielandschap en infrastructuur. Onze omgeving is '
#                  'hierbij voornamelijk gebaseerd op java en AWS, wij werken '
#                  'o.a. met Scala, Elasticsearch, Python, Docker en '
#                  'Airflow.</p>\n'
#                  '<p><strong>WIE BEN JE?</strong></p>\n'
#                  '<ul>\n'
#                  '<li>Je hebt zeer goede kennis van methodieken zoals SOA, '
#                  'TOGAF;</li>\n'
#                  '<li>Je hebt een technische achtergrond, als bijvoorbeeld '
#                  'developer, en bent in elk geval in staat om developers te '
#                  'adviseren en code te lezen;</li>\n'
#                  '<li>Je hebt kennis van API management, bouwen van software '
#                  'en integratie;</li>\n'
#                  '<li>Je hebt up to date kennis van security (SSO, openID '
#                  'connect);</li>\n'
#                  '<li>Je hebt kennis van data en informatie modellen;</li>\n'
#                  '<li>In een cloud omgeving voel je je thuis;</li>\n'
#                  '<li>Je bent communicatief sterk en in staat om met zowel '
#                  'developers als MT te schakelen op verschillende niveaus en '
#                  'doet dit comfortabel in zowel Nederlands als Engels;</li>\n'
#                  '<li>Ook al is programmeren geen dagelijkse taak meer, je '
#                  'vindt het leuk om zelf te puzzelen en hands-on dingen uit te '
#                  'proberen en mee te denken.</li>\n'
#                  '</ul>\n'
#                  '<p><strong>WAAROM RGN IT?</strong></p>\n'
#                  '<p>Tech en Touch. Wij geloven in de kracht van technologie, '
#                  'maar wél gecombineerd met persoonlijke aandacht. En dat '
#                  'geldt evengoed voor onze eigen medewerkers: wij zien jouw '
#                  'vooruitstrevende ideeën, maar vooral jou. Jouw werkplezier '
#                  'staat voorop. We zien jou als mens, en geven je de ruimte en '
#                  'ondersteuning om jouw beste zelf te zijn. Daarnaast bieden '
#                  'we:</p>\n'
#                  '<ul>\n'
#                  '<li>de kans om impact te maken op een groot '
#                  'transformatieproject;</li>\n'
#                  '<li>een interessant maandelijks salaris afhankelijk van je '
#                  'werkervaring;</li>\n'
#                  '<li>een benefit budget van 12,347% (incl. 8,5% vakantiegeld) '
#                  'dat je kan inzetten voor sport, extra opleidingsbudget, '
#                  'extra vrije tijd, of als leuke extra bonus;</li>\n'
#                  '<li>een lease auto of mobiliteitsbudget, laptop, telefoon en '
#                  'abonnement;</li>\n'
#                  '<li>25 vakantiedagen per jaar, met de optie er max. 26 bij '
#                  'te kopen;</li>\n'
#                  '<li>een interessante bonusregeling;</li>\n'
#                  '<li>de mogelijkheid om na 3 jaar een sabbatical te '
#                  'nemen;</li>\n'
#                  '<li>samenwerking met VSO voor internationale '
#                  'vrijwilligersprojecten;</li>\n'
#                  '<li>een organisatie die investeert in je groei en '
#                  'ontwikkeling.</li>\n'
#                  '</ul>\n'
#                  '<p>Nieuwsgierig geworden? We zien uit naar je '
#                  'sollicitatie.</p>\n'
#                  '<p>--</p>\n'
#                  '<p>Een VOG en/of een assessment kan onderdeel uitmaken van '
#                  'het selectieproces.</p>\n',
#   'how_to_apply': '<p>Ga direct naar <a '
#                   'href="https://www.werkenbijrandstad.nl/nl/nl/apply?jobSeqNo=RANEUKR16983EXTERNALNLNL&amp;utm_source=github&amp;utm_medium=paid&amp;utm_campaign=cr-it"><strong>het '
#                   'sollicitatieformulier</strong></a>!</p>\n',
#   'id': '8a3f8470-78be-41c9-acf6-dff2967ac96f',
#   'location': 'Diemen/Amsterdam',
#   'title': 'Software Architect',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/8a3f8470-78be-41c9-acf6-dff2967ac96f'},
#  {'company': 'Randstad Groep Nederland B.V.',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBdVNoIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--2eb5e267d5e57d8535d543fecb77c9fd029ad875/randstad-logo-share-blue.png',
#   'company_url': 'http://werkenbijrandstad.nl/',
#   'created_at': 'Thu Apr 22 17:52:33 UTC 2021',
#   'description': '<p>Met jouw expertise zorg je als fullstack java developer '
#                  'voor de meest plezierige en efficiënte klantervaring. Met '
#                  'jouw state-of-the-art-systemen verbeter je onze business en '
#                  'maak je echt impact!\n'
#                  'Want als je in ons tech team werkt, houd je jezelf en '
#                  'Nederland in beweging. Wij zijn continu bezig onze business '
#                  'en processen te optimaliseren, zodat we onze klanten en '
#                  'kandidaten meer gemak, snelheid en transparantie kunnen '
#                  'bieden. Impactvolle tech, daar doen we het voor.</p>\n'
#                  '<p><strong>WAT GA JE DOEN?</strong></p>\n'
#                  '<ul>\n'
#                  '<li>Samen met het team ontwikkelen van user stories op de '
#                  'backlog;</li>\n'
#                  '<li>Begeleiden van (meer junior) collega’s;</li>\n'
#                  '<li>Samenwerken met andere online teams;</li>\n'
#                  '<li>Devops activiteiten ontplooien zoals productie '
#                  'incidenten oplossen en voorkomen</li>\n'
#                  '<li>Uitvoeren en automatiseren van (regressie) testen</li>\n'
#                  '<li>Technisch refinen van user stories</li>\n'
#                  '<li>Testwerk</li>\n'
#                  '</ul>\n'
#                  '<p><strong>WAAR WERK JE?</strong></p>\n'
#                  '<p>We werken vanuit ons hoofdkantoor in Amsterdam (Diemen). '
#                  'Een ondernemende agile omgeving waar we in meer dan 24 '
#                  'DevOps-teams continu experimenteren met nieuwe '
#                  'technologieën. Jouw team bestaat uit vier tot zes software '
#                  'ontwikkelaars, designers, analisten en testers.\n'
#                  'We werken vanuit tribes. Door met meerdere tribes aan '
#                  'eenzelfde product of dienst te werken, ontstaat er een '
#                  "interessante kruisbestuiving tussen collega's van allerlei "
#                  'teams en disciplines binnen én buiten onze it afdeling. Zo '
#                  'houden we elkaar scherp en inspireren we elkaar. Maar '
#                  'natuurlijk blijf je binnen je eigen chapter ook brainstormen '
#                  'over ontwikkeling en technische problemen én schakel je met '
#                  'stakeholders in de organisatie, van product owners, security '
#                  'officers en directeuren; maar ook met eindgebruikers, '
#                  'recruiters, marketeers en kandidaten.</p>\n'
#                  '<p>Wat ongetwijfeld ook bijdraagt aan ons succes, is de '
#                  'diversiteit binnen onze teams. Zo zijn de vrouwen bij ons op '
#                  'de IT afdeling goed vertegenwoordigd met ruim 30%. Wij zijn '
#                  'er trots op, want we weten: gemengde teams – in de meest '
#                  'brede zin van het woord – presteren beter.</p>\n'
#                  '<p><strong>WIE BEN JE?</strong></p>\n'
#                  '<p>Jij hebt al wat jaren ervaring als software ontwikkelaar, '
#                  'uiteraard programmeer je voornamelijk in Java en ben je op '
#                  'zoek naar een plek waar je kan groeien. Daarnaast breng jij '
#                  'al wat ervaring met jou mee, namelijk:</p>\n'
#                  '<ul>\n'
#                  '<li>4 jaar aantoonbare ervaring in ontwikkelen van Java '
#                  'Webapplicaties, services (SOAP/REST) en business '
#                  'logica</li>\n'
#                  '<li>Java 8</li>\n'
#                  '<li>HTML / CSS / Javascript / Angular</li>\n'
#                  '<li>JSP</li>\n'
#                  '<li>JAVA Spring boot</li>\n'
#                  '<li>Docker Container</li>\n'
#                  '<li>Amazon AWS</li>\n'
#                  '<li>CI/CD</li>\n'
#                  '<li>ECS</li>\n'
#                  '</ul>\n'
#                  '<p>Jij hebt bij voorkeur ook ervaring met:</p>\n'
#                  '<ul>\n'
#                  '<li>Elasticsearch</li>\n'
#                  '<li>Gitlab / Jira / Jenkins / Kibana / Sonar</li>\n'
#                  '<li>Selenium / JUnit / Ready-API / SOAP-UI</li>\n'
#                  '<li>AWS</li>\n'
#                  '</ul>\n'
#                  '<p><strong>WAT BIEDEN WIJ?</strong></p>\n'
#                  '<ul>\n'
#                  '<li>Een warm bad, met fijne en inspirerende collega’s die '
#                  'voor je klaarstaan;</li>\n'
#                  '<li>Een leer/werktraject;</li>\n'
#                  '<li>Een marktconform salaris;</li>\n'
#                  '<li>25 vakantiedagen en 8,5% vakantietoeslag;</li>\n'
#                  '<li>Veel opleidingsmogelijkheden en ontwikkelkansen binnen '
#                  'Randstad Groep Nederland;</li>\n'
#                  '<li>Goede mobiliteitsregeling en laptop;</li>\n'
#                  '<li>Een ruim maandelijks benefit budget waarmee je zelf kunt '
#                  'kiezen tussen vrije tijd of geld of voor inzet van je budget '
#                  'voor oa een fiets, tablet, sportabonnement of '
#                  'opleiding;</li>\n'
#                  '<li>Een interessante bonusregeling met daarnaast '
#                  'mogelijkheid om 2x per jaar een outperformance bonus te '
#                  'behalen</li>\n'
#                  '</ul>\n'
#                  '<p><strong>WAAROM RGN IT?</strong></p>\n'
#                  '<p>Als je als fullstack java developer ergens impact hebt, '
#                  'dan is het hier wel. Wij ondersteunen onze '
#                  'HR-dienstverlening met hightech apps en software, die we '
#                  'continu verbeteren. Zodat onze mensen ervoor kunnen zorgen '
#                  'dat bijvoorbeeld jouw koffer op de band terecht komt op het '
#                  'vliegveld, jouw pakketjes netjes op tijd worden geleverd en '
#                  'goed verzorgt wordt in het ziekenhuis. Onze innovaties '
#                  'volgen elkaar in sneltreinvaart op. Wij geloven in de kracht '
#                  'van technologie, maar wél gecombineerd met persoonlijke '
#                  'aandacht. En dat geldt evengoed voor onze eigen medewerkers: '
#                  'wij zien jouw vooruitstrevende ideeën, maar vooral zien wij '
#                  'ook jou. Jouw werkplezier staat voorop.</p>\n'
#                  '<p>Wij bouwen aan hechte teams, waarin je alle ruimte krijgt '
#                  'om je ideeën waar te maken. En om jezelf te ontwikkelen. '
#                  'Durf je daar wat lef in te tonen? Top. Wij bieden je volop '
#                  'mogelijkheden om te groeien. Bij ons kies je dan ook niet '
#                  'voor een baan, je kiest voor een carrière. De enorme '
#                  'diversiteit aan functies binnen heel Randstad Groep '
#                  'Nederland biedt jou als developer interessante '
#                  'perspectieven. Wist je dat 80% van ons hoger management '
#                  'binnen onze eigen organisatie is opgeklommen? Kom erbij en '
#                  'groei!</p>\n'
#                  '<p>Helemaal zin om bij ons te beginnen? Wij kijken uit naar '
#                  'je sollicitatie.</p>\n'
#                  '<p>--</p>\n'
#                  '<p>Een VOG en/of een assessment kan onderdeel uitmaken van '
#                  'het selectieproces.</p>\n',
#   'how_to_apply': '<p>Ga direct naar <a '
#                   'href="https://www.werkenbijrandstad.nl/nl/nl/apply?jobSeqNo=RANEUKR18242EXTERNALNLNL&amp;utm_source=github&amp;utm_medium=paid&amp;utm_campaign=cr-it"><strong>het '
#                   'sollicitatieformulier</strong></a>!</p>\n',
#   'id': '2db8422f-da05-4821-9c44-86f2c3448ea9',
#   'location': 'Diemen/Amsterdam',
#   'title': 'Fullstack Java Developer',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/2db8422f-da05-4821-9c44-86f2c3448ea9'},
#  {'company': 'Livestorm',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBdnVoIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--ae48e3770ef8ca5c0c1a0dc4ff1808041cd802be/logo-site-livestorm-presta.jpeg',
#   'company_url': 'https://livestorm.co/',
#   'created_at': 'Fri Apr 23 11:53:03 UTC 2021',
#   'description': '<p>About Livestorm:</p>\n'
#                  '<p>Livestorm is the all-in-one video communication platform '
#                  'for companies looking to implement a powerful video '
#                  'communication strategy.</p>\n'
#                  '<p>Founded in 2016, Livestorm enables companies to promote, '
#                  'host and analyze their online events. We’re building the '
#                  'future of unified video communication: an all-in-one video '
#                  'communication platform that connects to your tools and lives '
#                  'in your browser. Livestorm is a browser-based platform that '
#                  'doesn’t require a download, or setup. You can use Livestorm '
#                  'for on-demand, live, or pre-recorded meetings or '
#                  'events.</p>\n'
#                  '<p>Livestorm has been built with ease-of-use in mind.</p>\n'
#                  '<p>We serve companies of all sizes, from startups to '
#                  'Fortune500. Front, Honda, Intercom or Spendesk trust '
#                  'Livestorm to organize their meetings, webinars or online '
#                  'events.</p>\n'
#                  '<p>Here are our core values:</p>\n'
#                  '<p>Stay curious: Be interested in the world around you.\n'
#                  'Remain humble: Keep learning and keep your ego in check.\n'
#                  'Be resourceful: Go that extra mile in the most efficient '
#                  'way.\n'
#                  'Own it: Take pride in what you do, own your wins, and '
#                  'fails.\n'
#                  'Be transparent: Sharing knowledge, learnings, feedback, and '
#                  'mistakes.</p>\n'
#                  '<p>Team description:\n'
#                  'As Livestorm is growing rapidly, our Team is aiming to '
#                  'develop our public API and everything that has to do with '
#                  'relevant data synchronisation between Livestorm and '
#                  '2nd/3rd-party softwares. Therefore, we are looking for a '
#                  'talented Back-End Engineer that can be a partner in helping '
#                  'us scale up our integrations ecosystem and make sure '
#                  'Livestorm can be connected with all relevant softwares in '
#                  'the industry.</p>\n'
#                  '<p>While Livestorm has headquarters in Paris, we are a '
#                  'remote-first company. As a matter of fact, Stormies are '
#                  'located between France, Germany, Greece, Mauritius, Spain, '
#                  'USA,... so we are looking for the best talent, no matter '
#                  'where you live.</p>\n'
#                  '<p>Missions:</p>\n'
#                  '<p>In this role, you will be responsible of:</p>\n'
#                  '<p>Designing, building and maintaining features in '
#                  'production\n'
#                  'Participating in Code Reviews and providing feedback to Team '
#                  'Members\n'
#                  'Sharing knowledge with everyone and helping your Team to '
#                  'grow\n'
#                  'Having the freedom to experiment\n'
#                  'Contributing to architectural and design decisions\n'
#                  'Monitoring the production to try to prevent any issue that '
#                  'could impact our customer experience</p>\n'
#                  '<p>Current Stack:</p>\n'
#                  '<p>Backend: Ruby 2.7.1 (soon Ruby 3), Rails 6, NodeJS '
#                  '12.20.1, Apollo Server\n'
#                  'Datastores: PostgreSQL / Redis\n'
#                  'Frontend: Vue.js\n'
#                  'Infra: AWS\n'
#                  'More on Stackshare 👉 <a '
#                  'href="https://stackshare.io/livestorm/livestorm">https://stackshare.io/livestorm/livestorm</a>\n'
#                  'Pré-requis du poste\n'
#                  'For this Backend Engineer Ruby - Integrations Squad role, we '
#                  'are looking for someone with the following experience:</p>\n'
#                  '<p>Code:</p>\n'
#                  '<p>At least 3 years experience in Ruby and Rails (Rails 5+)\n'
#                  'Previous experience with public API\n'
#                  'Rigorous about testing and code quality (TDD, acceptance '
#                  'tests, unit tests)\n'
#                  'Team fit:</p>\n'
#                  "<p>You're a team player and you have a sense of ownership.\n"
#                  'You can speak / write in English (French is a plus).\n'
#                  'Plus:</p>\n'
#                  '<p>Interested by micro-services oriented architectures\n'
#                  'You know how to implement event-based communication between '
#                  'micro-services.\n'
#                  'You have already worked in an agile environment and you '
#                  'loved it.\n'
#                  "You are curious about new languages and aren't afraid of "
#                  'using new patterns and structures.\n'
#                  'Moreover, we are looking for someone who can work in the '
#                  'Paris timezone (we accept a jet-lag of 2 hours '
#                  'maximum).</p>\n'
#                  '<p>Confidence can sometimes hold us back from applying for a '
#                  "job. But we'll let you in on a secret: there's no such thing "
#                  "as a 'perfect' candidate. So however you identify and "
#                  'whatever background you bring with you, please apply if this '
#                  'is a role that would make you excited to come into work '
#                  'every day.</p>\n'
#                  '<p>What it is like to join Livestorm and the Stormies:</p>\n'
#                  '<p>🗺 Work from anywhere you want:</p>\n'
#                  '<p>🏡 Home (participation for equipment and costs, according '
#                  'to our expense policy)\n'
#                  '🏢 Paris office (snacks, drinks, afterworks...)\n'
#                  '💼 Coworking space (covered up to €300 including VAT per '
#                  'month, or local currency equivalent)\n'
#                  '🚉 Business trips are covered (according to our internal '
#                  'T&amp;E policies)\n'
#                  '🚲 Sustainable mobility package for daily trips to go to '
#                  'work\n'
#                  '🎉 Cheer up your Stormie life:</p>\n'
#                  '<p>🎿 Off-sites twice a year\n'
#                  '🕹 Weekly activities (online board games, riddles...)\n'
#                  '👐 Teambuildings\n'
#                  '🗣 Monthly Talking times\n'
#                  '💙 Take care of yourself (with Moka.care)</p>\n'
#                  '<p>🤝 Participate to our referral program</p>\n'
#                  '<p>👶 Livestorm signed the "Parental act"</p>\n'
#                  '<p>And also, benefit from:</p>\n'
#                  '<p>🌍 All legal and mandatory benefits from your work country '
#                  'for EOR contracts.</p>\n'
#                  '<p>🇫🇷 All French legal benefits for French contracts: €9 of '
#                  'lunch vouchers with Swile (covered at 50%), health insurance '
#                  'with Alan (covered at 50%), transport subscription to go to '
#                  'work (covered at 50%), and CSE with cultural &amp; sport '
#                  'activities via Leeto.</p>\n',
#   'how_to_apply': '<p>Please apply on <a '
#                   'href="https://jobs.livestorm.co/o/backend-engineer-ruby-integrations-squad/c/new">https://jobs.livestorm.co/o/backend-engineer-ruby-integrations-squad/c/new</a></p>\n',
#   'id': 'b0f36645-4759-474a-b25e-9fa5d28cf595',
#   'location': 'full remote',
#   'title': 'Back-End Engineer Ruby - Integrations Squad',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/b0f36645-4759-474a-b25e-9fa5d28cf595'},
#  {'company': 'Remote',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBdnFoIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--faa6bd5b90a46cf3ac0157f4354dd101233e53c5/pJ-7_0_R_400x400.png',
#   'company_url': 'http://www.remote.com',
#   'created_at': 'Fri Apr 23 09:11:55 UTC 2021',
#   'description': '<p>Remote is THE global platform that enables companies to '
#                  'employ people anywhere in the world, taking away all legal '
#                  'and compliance complexities. Remote handles global payroll, '
#                  'benefits, taxes, and compliance for businesses big and '
#                  'small. (read more about <a '
#                  'href="https://remote.com/how-it-works">how it works</a>).\xa0'
#                  '</p>\n'
#                  '<p>We encourage folks from all ethnic groups, genders, '
#                  'sexuality, age and abilities to apply. We value kindness, '
#                  'ownership and team collaboration. You can check out our <a '
#                  'href="https://remote.com/handbook">public handbook</a>. to '
#                  'learn more about our culture. If this job description '
#                  'resonates with you, we want to hear from you!</p>\n'
#                  '<p><strong>How we work</strong></p>\n'
#                  '<p>Remote is fully remote (ah!) and we love <a '
#                  'href="https://www.notion.so/Working-Async-80c01cd443ad4c77a8ceaef7c5fba5d0">Working '
#                  'Async</a>. This means you get to do your own schedule no '
#                  'matter the timezone. The Remote Engineering team uses a '
#                  'simple approach to productivity and task management and you '
#                  'can read more about it in <a '
#                  'href="https://www.notion.so/remotecom/The-Remote-Flow-4ccc721f6dde40e4b5c91dd8e47e77c7">The '
#                  'Remote Flow</a>.</p>\n'
#                  "<p>The team you'll be joining: 33 engineers, spanning across "
#                  "Frontend, Backend, SRE and QA. We're organised into product "
#                  'teams composed with engineers, designers, product managers, '
#                  'operations and finance, each dedicated to achieving the same '
#                  'goals in a specific domain.</p>\n'
#                  '<p><strong>Requirements</strong></p>\n'
#                  '<ul>\n'
#                  '<li>Previous experience working as Frontend '
#                  'Engineer/Developer for at least 2 years</li>\n'
#                  '<li>Solid understanding of <strong>Javascript ES6</strong>\n'
#                  '</li>\n'
#                  '<li>Proficient with <strong>React</strong>\n'
#                  '</li>\n'
#                  '<li>Experience with <strong>Jest</strong> and <strong>React '
#                  'Testing Library</strong> or <strong>Enzyme</strong> in '
#                  'writing\xa0meaningful tests.\xa0</li>\n'
#                  '<li>Interest in build pages with performance, accessibility '
#                  'and API design in mind</li>\n'
#                  '<li>Attention to details when implementing UI mockups made '
#                  'by our amazing design team.</li>\n'
#                  "<li>It's not required to have experience working remotely, "
#                  'but considered a plus.</li>\n'
#                  '</ul>\n'
#                  '<p><strong>Nice to have</strong></p>\n'
#                  '<ul>\n'
#                  '<li>Nextjs</li>\n'
#                  '</ul>\n'
#                  '<p><strong>Benefits</strong></p>\n'
#                  '<ul>\n'
#                  '<li>Unlimited personal time off - Read our <a '
#                  'href="https://www.notion.so/Time-off-e2e71e5dcdef43ff82515d7c711ed4af">time '
#                  'off</a> policy</li>\n'
#                  '<li>The equipment/tools you need to do your job well and '
#                  'comfortable</li>\n'
#                  '<li>Training budget</li>\n'
#                  '<li>Good salary and company options</li>\n'
#                  '</ul>\n'
#                  '<p><strong>Application process</strong></p>\n'
#                  '<ul>\n'
#                  '<li>(async) Application is reviewed</li>\n'
#                  '<li>Interview with our recruiter</li>\n'
#                  '<li>Interview with your future manager (CTO)</li>\n'
#                  "<li>(async) code exercise (you're not expected to waste more "
#                  'than 2 - 4 hours)</li>\n'
#                  '<li>Interview with the team (without any manager in the call '
#                  'so you can really get to know the people and ask all you '
#                  'want to ask)</li>\n'
#                  '<li>(async) Reference calls</li>\n'
#                  '<li>(async) Offer</li>\n'
#                  '</ul>\n',
#   'how_to_apply': '<p><a '
#                   'href="https://grnh.se/f38c3f693us">https://grnh.se/f38c3f693us</a></p>\n',
#   'id': 'ab44fbb9-8ef5-46f8-af52-46c2ff03c622',
#   'location': 'Remote',
#   'title': 'Frontend Engineer',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/ab44fbb9-8ef5-46f8-af52-46c2ff03c622'},
#  {'company': 'Limango',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBc3FoIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--aa8c030695bdf8c2f0198aa9c1de4d97c3f666ed/Limango.jpg',
#   'company_url': 'https://www.limango.de/ehp',
#   'created_at': 'Thu Apr 22 11:57:55 UTC 2021',
#   'description': '<p><strong>OUR MISSION</strong></p>\n'
#                  '<p>limango is the Online Shop for families – We wow our '
#                  'customers every day with a fantastic range of brands at very '
#                  'attractive prices. Based in Munich, our 300 employees share '
#                  'a passion for families. We do everything we can to '
#                  'understand their needs and fulfil their wishes. limango has '
#                  'everything families need: Fashion for Babies, Kids, Women '
#                  'and Men as well as Homeware, Toys, Cosmetics and Family '
#                  'holidays. At limango you’ll find both classic brands and '
#                  'upcoming brands from across Europe. Founded in 2007 and a '
#                  'member of the Otto Group since 2009 limango now has over 22 '
#                  'million members across Germany, Austria, France, the '
#                  'Netherlands and Poland and sells over 40 000 products daily '
#                  'to German customers alone. We want to continue to grow and '
#                  'win the trust of all mums in Europe. To help us achieve '
#                  'this, we’re looking for motivated, talented individuals to '
#                  'work with us and be a part of something big.</p>\n'
#                  '<p><strong>YOUR JOB</strong></p>\n'
#                  '<ul>\n'
#                  '<li>In the limango IT you get the chance to contribute your '
#                  'own ideas and know-how to the development of services all '
#                  'around the different processes of our ecommerce '
#                  'business</li>\n'
#                  '<li>Together with our experienced and international '
#                  'development teams you will improve and expand our php based '
#                  'backend CRM systems</li>\n'
#                  '<li>You will become part of our well-rehearsed agile teams '
#                  'of versatile and experienced developers and a dedicated '
#                  'product owner</li>\n'
#                  '</ul>\n'
#                  '<p><strong>YOUR PROFILE</strong></p>\n'
#                  '<ul>\n'
#                  '<li>A degree with a focus on IT or a comparable '
#                  'training</li>\n'
#                  '<li>You have 1-2 years experience in the development of '
#                  'scalable eCommerce applications in common PHP frameworks '
#                  'such as Symfony3+ as well as knowledge of OOP and design '
#                  'patterns</li>\n'
#                  '<li>You bring practical experience with RESTful APIs and '
#                  'service-oriented architecture</li>\n'
#                  '<li>You have profound experience in relational databases '
#                  '(MySQL/MariaDB)</li>\n'
#                  '<li>DevOps and GoLang experience are desirable</li>\n'
#                  '<li>A well-functioning tool is not enough for you - you '
#                  'enjoy optimizing complex IT processes!</li>\n'
#                  '</ul>\n'
#                  '<p><strong>OUR OFFER</strong></p>\n'
#                  '<ul>\n'
#                  '<li>Challenging tasks, independent work and a great deal of '
#                  'creative freedom in a working environment that burns for '
#                  'results and is happy to be measured against them</li>\n'
#                  '<li>An open, team-oriented working atmosphere</li>\n'
#                  '<li>A steep learning curve in a dynamic company with '
#                  'international orientation</li>\n'
#                  "<li>A great office in Munich's Tech-Spot with probably the "
#                  'coolest roof terrace in the city</li>\n'
#                  '<li>Corporate events, fresh fruit and soft drinks</li>\n'
#                  '</ul>\n'
#                  '<p>Interested? We look forward to receiving your application '
#                  'including CV, salary requirements and your earliest possible '
#                  'starting date.</p>\n'
#                  '<p><img '
#                  'src="https://camo.githubusercontent.com/5847810e6df3e310e9a7f0359b12199b8400f650/68747470733a2f2f742e676f686972696e672e636f6d2f682f66663336323231373239383466626366656631313864613139653663316237303434313365376665656136353936346631626561313463353734626531626662"></p>\n',
#   'how_to_apply': '<p><a '
#                   'href="https://t.gohiring.com/h/076f63218fd916966f368984c132b7e532a45727014fa66f239f48fed4be0d9d">application '
#                   'form</a></p>\n',
#   'id': '7aa4fa1a-7d57-43a1-9f5b-55bdacf3e6a6',
#   'location': 'Munich',
#   'title': 'Junior PHP Backend Developer (m/w/d)',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/7aa4fa1a-7d57-43a1-9f5b-55bdacf3e6a6'},
#  {'company': 'FundraisingBox c/o Wikando GmbH',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBc09oIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--23ab23411072a59fb07d086b2aa0924a2d470383/FundraisingBox%20c-o%20Wikando%20GmbH.jpeg',
#   'company_url': 'https://www.fundraisingbox.com/',
#   'created_at': 'Thu Apr 22 11:08:41 UTC 2021',
#   'description': '<p>Wir sind digitale Entwicklungshelfer und ein echtes '
#                  'Remote-Team! Der Firmensitz unserer Wikando GmbH ist zwar in '
#                  'Augsburg, aber wir sind komplett virtuell organisiert. Das '
#                  'hat den großen Vorteil, dass Du nicht umziehen musst, und '
#                  'von überall aus - mit Internetanschluss, versteht sich - mit '
#                  'uns arbeiten kannst. Trotzdem sind wir ein sehr enges, '
#                  'vertrautes Team und besitzen auch eine Teeküche ;-)</p>\n'
#                  '<p>Ob Du digitaler Nomade oder Familienmensch bist, unser '
#                  'Modell ermöglicht Dir Deine optimale Work-Life-Balance. '
#                  'Deine Stelle ist remote und unbefristet. Wir würden uns '
#                  'freuen, Dich kennenzulernen und mit an Bord zu nehmen! '
#                  'Schick uns Deine Bewerbung.</p>\n'
#                  '<p><strong>Das machen wir</strong></p>\n'
#                  '<p>Unsere Mission ist es, Non-Profits weltweit durch unser '
#                  'Experten-Team und Technologien zu befähigen, neue digitale '
#                  'Kanäle des Spendens zu erschließen, manuelle Prozesse zu '
#                  'digitalisieren und den NGOs dabei zu helfen wirksame '
#                  'Entscheidungen bezüglich ihrer Projekte zu treffen.</p>\n'
#                  '<p>Dabei begleiten wir das komplette Spendenerlebnis: Vom '
#                  'digitalen Fundraising (z. B. mit unseren '
#                  'Online-Spendenformularen oder einer Crowdfunding-Kampagne), '
#                  'dem Bezahlen mit neuesten Payment-Methoden (z. B. Google '
#                  'oder Apple Pay) bis hin zum Spender:innenmanagement (z. B. '
#                  'mit unserem eigenen CRM-System oder Anbindung von externen '
#                  'E-Marketing-Diensten, CRMs, usw.).</p>\n'
#                  '<p>Wir sind ein leidenschaftliches Team kluger Köpfe und '
#                  'haben unglaublich viel Spaß an der Entwicklung neuer '
#                  'Lösungen, um Hilfsorganisationen weltweit dabei zu helfen, '
#                  'schneller und einfacher Spenden zu sammeln und zu verwalten. '
#                  'Die Arbeit in unserem wachsenden IT-Unternehmen bietet dir '
#                  'alle Freiheiten und Möglichkeiten, deine Ideen zu '
#                  'verwirklichen!</p>\n'
#                  '<p>Wir würden uns über deine Unterstützung dabei sehr '
#                  'freuen!</p>\n'
#                  '<p>Übrigens: Wir haben unseren Firmensitz in Augsburg, sind '
#                  'aber komplett virtuell organisiert. Das hat den großen '
#                  'Vorteil, dass Du von überall aus mit uns arbeiten kannst. Ob '
#                  'digitale:r Nomad:in oder Familienmensch: Unser Modell '
#                  'ermöglicht dir deine optimale Work-Life-Balance.\n'
#                  'Du kannst sofort starten. Die Stelle ist Vollzeit und '
#                  'unbefristet.</p>\n'
#                  '<p><strong>Deine Aufgaben bei uns</strong></p>\n'
#                  '<p><strong>Agile Weiterentwicklung aller Produkte der '
#                  'FundraisingBox</strong>\n'
#                  'In unserem integrierten Produktentwicklungsteam konzipierst '
#                  'und entwickelst du neue Features im Bereich '
#                  'Online-Fundraising, treibst mit neuen Technologien die '
#                  'Themen Payments oder API-Connectoren voran oder verbesserst '
#                  'kontinuierlich die Funktionalität unseres CRM-Systems.. '
#                  'Dabei nutzt du die gängigen PHP/CSS/JavaScript-Frameworks '
#                  'und begleitest den gesamten Software Life-Cycle '
#                  'Prozess.</p>\n'
#                  '<p><strong>Integration von innovativen '
#                  'Technologien</strong>\n'
#                  'Du lernst innovative  Software-, Service- und '
#                  'Payment-Provider kennen oder schlägst eigene Technologien '
#                  'vor, liest dich in API-Dokumentationen ein und integrierst '
#                  'modernste Webservices in die FundraisingBox sowie in unser '
#                  'Payment-Gateway.</p>\n'
#                  '<p><strong>Individuelle Beratung von '
#                  'Non-Profit-Kund:innen</strong>\n'
#                  'Wenn du möchtest, stehst du in Webinaren und Workshops '
#                  'Kund:innen und deren Entwickler:innen oder Agenturen mit Rat '
#                  'und Tat zur Seite, um sie mit unseren FundraisingBox '
#                  'Technologien bei ihren individuellen Projekten zu '
#                  'unterstützen.</p>\n'
#                  '<p><strong>Kontinuierliche Optimierung bestehender '
#                  'Strukturen</strong>\n'
#                  'Du lässt dein Know-How und deine Erfahrungen in unsere '
# ...
#                  'insurance, health insurance, investment and retirement '
#                  'savings. We offer a broad portfolio of financial and benefit '
#                  'plan solutions for individuals, families, businesses and '
#                  'organizations.\u202f\xa0</p>\n'
#                  '<p>We are committed to providing an inclusive, accessible '
#                  'environment, where all employees and customers feel valued, '
#                  'respected and supported. We are dedicated to building a '
#                  'workforce that reflects the diversity of the communities in '
#                  'which we live, and to creating an environment where every '
#                  'employee\u202fhas the opportunity to\u202freach their '
#                  'potential.\u202f\xa0</p>\n'
#                  '<p>Canada Life\u202fwould like to thank all applicants, '
#                  'however only those who qualify for an interview will be '
#                  'contacted\u202f\xa0</p>\n',
#   'how_to_apply': '<p>Submit an application here: <a '
#                   'href="https://bit.ly/3a53Wue">https://bit.ly/3a53Wue</a> or '
#                   'email a copy of your resume directly to <a '
#                   'href="mailto:aynsley.hamilton@canadalife.com">aynsley.hamilton@canadalife.com</a></p>\n',
#   'id': '5514a0a7-7fe0-4647-9108-8243d453bd6b',
#   'location': 'Toronto, Ontario, Canada',
#   'title': 'Software Developer',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/5514a0a7-7fe0-4647-9108-8243d453bd6b'},
#  {'company': 'kognition',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBbjZnIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--35cd9cd717939c8c544d0d49474428b858be3bd5/Kognition-Logo.png',
#   'company_url': 'https://kognition.ai',
#   'created_at': 'Mon Apr 12 15:05:51 UTC 2021',
#   'description': '<p>Job Title: DevOps Engineer\n'
#                  'Company: Kognition AI\n'
#                  'Dept./Group: Engineering\n'
#                  'Employment Terms: Contract to hire (3-6 months) for '
#                  'Full-Time\n'
#                  'Position reports to: Chief Technology Officer\n'
#                  'Number of Direct Reports: 0-3\n'
#                  'Compensation: Market salary rate + equity incentives + full '
#                  'benefits upon hiring</p>\n'
#                  '<p>Position Summary (Purpose of job):</p>\n'
#                  '<p>Kognition is an enterprise AI software company that '
#                  'develops an interoperability infrastructure for smart '
#                  "buildings and smart cities. Kognition's AI-powered policy "
#                  'engine automates complex business operations in real-time. '
#                  'We are looking for a full stack senior software engineer to '
#                  'join our dynamic and rapidly growing R&amp;D team. We look '
#                  'at software development as a craft that requires deliberate '
#                  'practice, curiosity, and passion. If you work hard, have an '
#                  'innovative mindset, and love building great software, we '
#                  'should talk!</p>\n'
#                  '<p>As a DevOps Engineer, you will be a key part of our '
#                  'research and development and operations team that builds and '
#                  'operates our core products. You will design, develop, '
#                  'deploy, document, test, and debug our on-prem and cloud '
#                  'Kubernetes infrastructure. You will work as part of a '
#                  'high-powered team, in an agile fashion, towards an end goal '
#                  'of making the world smarter, safer and more secure.</p>\n'
#                  '<p>Key Responsibilities:</p>\n'
#                  '<ol>\n'
#                  '<li>\n'
#                  '<p>Analyze, design, and plan complex software solutions -- '
#                  '20%</p>\n'
#                  '</li>\n'
#                  '<li>\n'
#                  '<p>Lead programming effort -- 40%</p>\n'
#                  '</li>\n'
#                  '<li>\n'
#                  '<p>Performs complex bug verification, testing, and program '
#                  'support for various products -- 30%</p>\n'
#                  '</li>\n'
#                  '<li>\n'
#                  '<p>Provide technical assistance, mentorship and guidance to '
#                  'junior software developers -- 10%</p>\n'
#                  '</li>\n'
#                  '</ol>\n'
#                  '<p>Minimum Job Qualifications:</p>\n'
#                  '<p>Education/Training: Bachelors or Masters degree; Computer '
#                  'Science, Engineering, Management Information Systems, or '
#                  'related</p>\n'
#                  '<p>Business Experience:\n'
#                  '5+ years experience in IT operations, software '
#                  'engineering</p>\n'
#                  '<p>Critical Skills:</p>\n'
#                  '<p>-Strong application design skills and understanding of '
#                  'AWS cloud services and Kubernetes\n'
#                  '-Thorough understanding and experience working with scripts '
#                  'and scripting languages (e.g. Bash, Python)\n'
#                  '-Experience working with containers and container '
#                  'orchestration systems and specifically Kubernetes.\n'
#                  '-Experience writing and deploying Helm charts on Kubernetes\n'
#                  '-Experience developing highly available, highly scalable web '
#                  'applications\n'
#                  '-Experience with real-time pub/sub, flow, and streaming '
#                  'frameworks (e.g. Kafka, NiFi)\n'
#                  '-Experience with NoSQL databases (e.g. MongoDB, Cassandra, '
#                  'CouchDB) and replication\n'
#                  '-Experience working with various testing methodologies, '
#                  'including test-driven development (TDD), behavior-driven '
#                  'development (BDD), and unit testing\n'
#                  '-Experience with performance-monitoring and tuning of '
#                  'complex applications\n'
#                  '-Experience deploying, managing, and configuring '
#                  'applications both on-prem and in-cloud (AWS, Google Cloud, '
#                  'Azure)\n'
#                  '-Solid understanding of the Software Development Life Cycle '
#                  'in Agile environment (e.g. Kanban, Scrum)</p>\n'
#                  '<p>Desired Skills:</p>\n'
#                  '<p>-Experience with machine vision (i.e. openCV)\n'
#                  '-Experience with web based video processing, video '
#                  'analytics, media compression and encoding (i.e. Gstreamer, '
#                  'ffmpeg)\n'
#                  '-Experience working with deep net frameworks (e.g. '
#                  'Tensorflow, Torch, mxnet, gluon)\n'
#                  '-Experience working with native code in non-native languages '
#                  '(e.g. JNA, JNI, DllImport)\n'
#                  '-Security industry experience</p>\n'
#                  '<p>Additional Specialized Knowledge/Skills:</p>\n'
#                  '<p>-Passion for cutting-edge software design and '
#                  'development\n'
#                  '-Highly motivated and self-directed\n'
#                  '-Excellent written and oral communication skills\n'
#                  '-Keen attention to detail\n'
#                  '-Proven analytical, evaluative, and problem-solving '
#                  'abilities\n'
#                  '-Ability to effectively prioritize and execute tasks in a '
#                  'high-pressure environment\n'
#                  '-Exceptional customer service orientation\n'
#                  '-Extensive experience working in a team-oriented, '
#                  'collaborative environment\n'
#                  '-Willingness to mentor and train junior developers\n'
#                  '-Willingness to support resolution of escalated technical '
#                  'support issues\n'
#                  '-Willingness to travel to client locations is preferred</p>\n'
#                  '<p>Work Location During Pandemic:\n'
#                  'Fully remote</p>\n'
#                  '<p>Post-Pandemic Location:\n'
#                  'Position will be located in our Philadelphia, PA office '
#                  'after the pandemic is over\n'
#                  'WFH flexibility with a focus on in-office availability '
#                  '(post-pandemic)\n'
#                  'General Office- travel less than 10%.</p>\n',
#   'how_to_apply': '<p>Email resume to: <a '
#                   'href="mailto:jobs@kognition.ai">jobs@kognition.ai</a></p>\n',
#   'id': 'a17c1673-09b8-42e1-9ebf-6b8e97a40cc4',
#   'location': 'Philadelphia, PA or remote',
#   'title': 'DevOps Engineer',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/a17c1673-09b8-42e1-9ebf-6b8e97a40cc4'},
#  {'company': 'kognition',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBbmlnIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--e9cc81f3fdd0714ab6f095c69dde26b36da42744/Kognition-Logo.png',
#   'company_url': 'https://kognition.ai',
#   'created_at': 'Mon Apr 12 14:34:59 UTC 2021',
#   'description': '<p>Job Title: Senior UI / UX Engineer\n'
#                  'Company: Kognition AI\n'
#                  'Dept./Group: Engineering\n'
#                  'Employment Terms: Contract to hire (3-6 months) for '
#                  'Full-Time\n'
#                  'Position reports to: Chief Technology Officer\n'
#                  'Number of Direct Reports: 0-3\n'
#                  'Compensation: Market salary rate + equity incentives + full '
#                  'benefits upon hiring</p>\n'
#                  '<p>Position Summary (Purpose of job):</p>\n'
#                  '<p>Kognition is an enterprise AI software company that '
#                  'develops an interoperability infrastructure for smart '
#                  "buildings and smart cities. Kognition's AI-powered policy "
#                  'engine automates complex business operations in real-time. '
#                  'We are looking for a full stack senior software engineer to '
#                  'join our dynamic and rapidly growing R&amp;D team. We look '
#                  'at software development as a craft that requires deliberate '
#                  'practice, curiosity, and passion. If you work hard, have an '
#                  'innovative mindset, and love building great software, we '
#                  'should talk!</p>\n'
#                  '<p>As a Senior UI Engineer, you will be a key part of our '
#                  'research and development team that builds our core products. '
#                  'You will design, develop, document, test and debug Web UI '
#                  'applications and services. You will work as part of a '
#                  'high-powered team, in an agile fashion, towards an end goal '
#                  'of making the world smarter, safer and more secure.</p>\n'
#                  '<p>Key Responsibilities:</p>\n'
#                  '<ol>\n'
#                  '<li>\n'
#                  '<p>Analyze, plan, and design easy-to-use user interfaces '
#                  'infocore products -- 20%</p>\n'
#                  '</li>\n'
#                  '<li>\n'
#                  '<p>Lead programming effort -- 40%</p>\n'
#                  '</li>\n'
#                  '<li>\n'
#                  '<p>Performs complex bug verification, testing, and program '
#                  'support for various products -- 30%</p>\n'
#                  '</li>\n'
#                  '<li>\n'
#                  '<p>Provide technical assistance, mentorship and guidance to '
#                  'junior software developers -- 10%</p>\n'
#                  '</li>\n'
#                  '</ol>\n'
#                  '<p>Minimum Job Qualifications:</p>\n'
#                  '<p>Education/Training: Bachelors or Masters degree; Computer '
#                  'Science, Engineering, Management Information Systems, or '
#                  'related</p>\n'
#                  '<p>Business Experience:\n'
#                  '5+ yrs experience web development\n'
#                  '3+ yrs experience with React.js and Node.js</p>\n'
#                  '<p>Critical Skills:</p>\n'
#                  '<p>-Strong application design skills and understanding of '
#                  'single page app design patterns\n'
#                  '-Thorough understanding of modern web languages (e.g. HTML5, '
#                  'CSS3 and ES6+)\n'
#                  '-Thorough understanding modern web build chain technologies '
#                  'and purpose (e.g. webpack, gulp)\n'
#                  '-Thorough understanding of React.js\n'
#                  '-Comprehensive knowledge of available library options within '
#                  'the React ecosystem (e.g. Redux, Material-UI, etc.)\n'
#                  '-Experience developing highly available, highly scalable web '
#                  'applications\n'
#                  '-Experience building and integrating RESTful APIs, and '
#                  'integrating back-end services\n'
#                  '-Experience with RDBMS and NoSQL databases\n'
#                  '-Experience working with various testing methodologies, '
#                  'including test-driven development (TDD), behavior-driven '
#                  'development (BDD), and unit testing\n'
#                  '-Experience with performance-monitoring and tuning of web '
#                  'stack applications\n'
#                  '-Experience deploying, managing, and configuring '
#                  'applications both on-prem and in-cloud (e.g. AWS, Google '
#                  'Cloud, Azure)\n'
#                  '-Solid understanding of the Software Development Life Cycle '
#                  'and various Agile methodologies (e.g. Kanban, Scrum)</p>\n'
#                  '<p>Desired Skills:</p>\n'
#                  '<p>-Experience working with containers and container '
#                  'orchestration systems (e.g. Docker, Kubernetes, DC/OS, '
#                  'Nomad)\n'
#                  '-Experience with machine vision (i.e. openCV)\n'
#                  '-Experience with web based video processing, video '
#                  'analytics, media compression and encoding (i.e. Gstreamer, '
#                  'ffmpeg)</p>\n'
#                  '<p>Additional Specialized Knowledge/Skills:</p>\n'
#                  '<p>-Passion for cutting-edge software design and '
#                  'development\n'
#                  '-Highly motivated and self-directed\n'
#                  '-Excellent written and oral communication skills\n'
#                  '-Keen attention to detail\n'
#                  '-Proven analytical, evaluative, and problem-solving '
#                  'abilities\n'
#                  '-Ability to effectively prioritize and execute tasks in a '
#                  'high-pressure environment\n'
#                  '-Focus on user experience\n'
#                  '-Extensive experience working in a team-oriented, '
#                  'collaborative environment\n'
#                  '-Willingness to mentor and train junior developers\n'
#                  '-Willingness to support resolution of escalated technical '
#                  'support issues</p>\n'
#                  '<p>Work Location During Pandemic:\n'
#                  'Fully remote</p>\n'
#                  '<p>Post-Pandemic Location:\n'
#                  'Position will be located in our Philadelphia, PA office '
#                  'after the pandemic is over\n'
#                  'WFH flexibility with a focus on in-office availability '
#                  '(post-pandemic)\n'
#                  'General Office- travel less than 10%.</p>\n',
#   'how_to_apply': '<p>Email your resume to <a '
#                   'href="mailto:jobs@kognition.ai">jobs@kognition.ai</a></p>\n',
#   'id': '3e546b76-6555-41a5-a0f3-0b98f800e04e',
#   'location': 'Philadelphia, PA or remote',
#   'title': 'Senior UI / UX Engineer - React, Node.js',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/3e546b76-6555-41a5-a0f3-0b98f800e04e'}]

# %%
df=pd.DataFrame(response)
print(df.columns)
# Out:
# Index(['id', 'type', 'url', 'created_at', 'company', 'company_url', 'location',
#        'title', 'description', 'how_to_apply', 'company_logo'],
#       dtype='object')

# %%
#df = pd.read_json('data')
df=df[['id', 'type', 'url', 'created_at', 'company', 'company_url', 'location',
       'title', 'description', 'how_to_apply', 'company_logo']]
df.head()
# Out:
#                                      id       type  \
# 0  4502c26a-af2f-4cd1-a3e4-a25cf813bfbf  Full Time
# 1  8a3f8470-78be-41c9-acf6-dff2967ac96f  Full Time
# 2  2db8422f-da05-4821-9c44-86f2c3448ea9  Full Time
# 3  b0f36645-4759-474a-b25e-9fa5d28cf595  Full Time
# 4  ab44fbb9-8ef5-46f8-af52-46c2ff03c622  Full Time
#
#                                                  url  \
# 0  https://jobs.github.com/positions/4502c26a-af2...
# 1  https://jobs.github.com/positions/8a3f8470-78b...
# 2  https://jobs.github.com/positions/2db8422f-da0...
# 3  https://jobs.github.com/positions/b0f36645-475...
# 4  https://jobs.github.com/positions/ab44fbb9-8ef...
#
#                      created_at                        company  \
# 0  Fri Apr 23 08:23:08 UTC 2021  Randstad Groep Nederland B.V.
# 1  Thu Apr 22 16:15:11 UTC 2021  Randstad Groep Nederland B.V.
# 2  Thu Apr 22 17:52:33 UTC 2021  Randstad Groep Nederland B.V.
# 3  Fri Apr 23 11:53:03 UTC 2021                      Livestorm
# 4  Fri Apr 23 09:11:55 UTC 2021                         Remote
#
#                          company_url          location  \
# 0  https://www.werkenbijrandstad.nl/  Diemen/Amsterdam
# 1  https://www.werkenbijrandstad.nl/  Diemen/Amsterdam
# 2       http://werkenbijrandstad.nl/  Diemen/Amsterdam
# 3              https://livestorm.co/       full remote
# 4              http://www.remote.com            Remote
#
#                                          title  \
# 0                                Data Engineer
# 1                           Software Architect
# 2                     Fullstack Java Developer
# 3  Back-End Engineer Ruby - Integrations Squad
# 4                            Frontend Engineer
#
#                                          description  \
# 0  <p>Data Engineer, Everyday people employed thr...
# 1  <p>Als je bij Randstad Groep Nederland IT werk...
# 2  <p>Met jouw expertise zorg je als fullstack ja...
# 3  <p>About Livestorm:</p>\n<p>Livestorm is the a...
# 4  <p>Remote is THE global platform that enables ...
#
#                                         how_to_apply  \
# 0  <p>Apply directly through <a href="https://www...
# 1  <p>Ga direct naar <a href="https://www.werkenb...
# 2  <p>Ga direct naar <a href="https://www.werkenb...
# 3  <p>Please apply on <a href="https://jobs.lives...
# 4  <p><a href="https://grnh.se/f38c3f693us">https...
#
#                                         company_logo
# 0  https://jobs.github.com/rails/active_storage/b...
# 1  https://jobs.github.com/rails/active_storage/b...
# 2  https://jobs.github.com/rails/active_storage/b...
# 3  https://jobs.github.com/rails/active_storage/b...
# 4  https://jobs.github.com/rails/active_storage/b...

# %%
df.replace(np.NAN,'NA', inplace = True)
